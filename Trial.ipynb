# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
import numpy as np

df = pd.read_excel('/media/sambit/HDD/Sambit/Projects/Radiomics_Project1/Data/Jobba med_Naf_Final Glimrad01_outcome (2)_KH.xlsx', sheet_name = 'FINAL')
df = df[['Glim_FOU','Age', '\npT\n']]
df = df.rename(columns={"Glim_FOU":"id", "\npT\n":"outcome", "Age":"age"})
df['id'] = df['id'].astype(str)
df['id'] = 'Pat' + df['id']
# treatment = [1 for i in range(len(df))]
# df["treatment"] = treatment
df['outcome'] = df['outcome'].astype(str)
replace_keys1 = ['saknas', 'nan']
replace_keys2 = ['3d', '3b', '4a', '2', '3', '3a', '3c', '4b', '1sm2', '1sm3']

# df.loc[df['outcome'] == '2', "outcome"] = '0'
df.loc[df['outcome'] == 'Tis', "outcome"] = '0'


for i in replace_keys1:
    df.loc[df['outcome'] == i, "outcome"] = '-1'
    
for i in replace_keys2:
    df.loc[df['outcome'] == i, "outcome"] = '1'

df['outcome'] = df['outcome'].astype('int64')

print(np.unique(df['outcome'], return_counts=True))
df.head()
# Out:
# <ipython-input-30-376a0dc69f82>:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# (array([-1,  0,  1]), array([ 2, 21, 98]))
#      id  age  outcome
# 0  Pat1  80   1
# 1  Pat2  77   1
# 2  Pat3  76  -1
# 3  Pat4  74   1
# 4  Pat5  73   1

# %%
df_0 = df[df['outcome'] == 0].reset_index(drop=True)
df_0.head()
# Out:
#       id  age  outcome
# 0  Pat7   69   0
# 1  Pat8   69   0
# 2  Pat11  67   0
# 3  Pat27  59   0
# 4  Pat30  59   0

# %%
# df_new = pd.merge(df, df_0, on="id", how="inner")
df_new = pd.concat([df, df_0])
# df_new = pd.concat([df_new, df_0]).reset_index(drop=True)

df_new.shape
# Out:
# (142, 3)

# %%
df_new
# Out:
#          id  age  outcome
# 0    Pat1    80   1
# 1    Pat2    77   1
# 2    Pat3    76  -1
# 3    Pat4    74   1
# 4    Pat5    73   1
# 5    Pat6    73   1
# 6    Pat7    69   0
# 7    Pat8    69   0
# 8    Pat9    68   1
# 9    Pat10   71   1
# 10   Pat11   67   0
# 11   Pat12   68   1
# 12   Pat13   66   1
# 13   Pat14   66   1
# 14   Pat15   68   1
# 15   Pat16   68   1
# 16   Pat17   66   1
# 17   Pat18   66   1
# 18   Pat19   66   1
# 19   Pat20   67   1
# 20   Pat21   66   1
# 21   Pat22   65   1
# 22   Pat24   63   1
# 23   Pat25   66   1
# 24   Pat26   60   1
# 25   Pat27   59   0
# 26   Pat28   60   1
# 27   Pat29   59   1
# 28   Pat30   59   0
# 29   Pat31   58   0
# 30   Pat32   57  -1
# 31   Pat33   54   1
# 32   Pat34   55   1
# 33   Pat35   54   1
# 34   Pat36   51   0
# 35   Pat37   43   1
# 36   Pat38   44   0
# 37   Pat39   42   0
# 38   Pat40   42   1
# 39   Pat41   38   1
# 40   Pat42   86   1
# 41   Pat43   76   1
# 42   Pat44   84   1
# 43   Pat45   83   1
# ...

# %%
np.unique(df_new['outcome'], return_counts=True)
# Out:
# (array([-1,  0,  1]), array([ 2, 42, 98]))

# %%
df_new.to_csv("/media/sambit/HDD/Sambit/Projects/Radiomics_Project1/Data/manual_features/manual_features_new.csv")

# %%
df = pd.read_csv("/media/sambit/HDD/Sambit/Projects/Radiomics_Project1/Code/Radiomics/feature_extraction/selection_features.csv", delimiter=';')
df.shape
# Out:
# (104, 1344)

# %%
['wavelet-HL_glrlm_LongRunEmphasis_T2_T2M', 'gradient_glrlm_GrayLevelNonUniformity_T2_T2M', 'gradient_gldm_GrayLevelNonUniformity_T2_T2M ', 'wavelet-HL_glszm_ZoneVariance_T2_T2M', 'original_firstorder_Skewness_T2_T2M', 'wavelet-HL_glrlm_RunVariance_T2_T2M', 'wavelet-HL_glcm_ClusterProminence_T2_T2M', 'lbp-2D_firstorder_RootMeanSquared_T2_T2M', 'wavelet-HL_glcm_DifferenceVariance_T2_T2M', 'wavelet-HL_glcm_Contrast_T2_T2M', 'lbp-2D_glcm_Correlation_T2_T2M', 'wavelet-HH_glcm_Contrast_T2_T2M', 'wavelet-HH_glszm_ZoneVariance_T2_T2M', 'logarithm_glrlm_LongRunEmphasis_T2_T2M', 'logarithm_glrlm_RunVariance_T2_T2M']

# %%
*** MaxRel features ***
Order 	 Fea 	 Name 	 Score
1 	 800 	 wavelet-HL_glrlm_LongRunEmphasis_T2_T2M 	 0.116
2 	 612 	 gradient_glrlm_GrayLevelNonUniformity_T2_T2M 	 0.116
3 	 648 	 gradient_gldm_GrayLevelNonUniformity_T2_T2M 	 0.116
4 	 827 	 wavelet-HL_glszm_ZoneVariance_T2_T2M 	 0.110
5 	 33 	 original_firstorder_Skewness_T2_T2M 	 0.102
6 	 808 	 wavelet-HL_glrlm_RunVariance_T2_T2M 	 0.099
7 	 774 	 wavelet-HL_glcm_ClusterProminence_T2_T2M 	 0.091
8 	 1228 	 lbp-2D_firstorder_RootMeanSquared_T2_T2M 	 0.087
9 	 781 	 wavelet-HL_glcm_DifferenceVariance_T2_T2M 	 0.085
10 	 777 	 wavelet-HL_glcm_Contrast_T2_T2M 	 0.085
11 	 1238 	 lbp-2D_glcm_Correlation_T2_T2M 	 0.084
12 	 869 	 wavelet-HH_glcm_Contrast_T2_T2M 	 0.080
13 	 919 	 wavelet-HH_glszm_ZoneVariance_T2_T2M 	 0.080
14 	 524 	 logarithm_glrlm_LongRunEmphasis_T2_T2M 	 0.080
15 	 532 	 logarithm_glrlm_RunVariance_T2_T2M 	 0.080
